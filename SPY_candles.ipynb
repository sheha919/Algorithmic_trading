# %%
#! pip install mplfinance

# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf
# Out:
# C:\Users\sheha\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\sheha\AppData\Local\Temp\ipykernel_11792\1202515694.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
file = 'SPY_5Y_Daily_candle.xlsx'
df =  pd.read_excel(file, sheet_name = 'original')

# %%
df
# Out:
#                           Date    Open    High     Low   Close  % Change  \
# 0     2019-02-05T08:00:00.000Z  272.44  273.44  271.88  273.10    0.4192
# 1     2019-02-06T08:00:00.000Z  272.79  273.34  271.92  272.74   -0.1318
# 2     2019-02-07T08:00:00.000Z  270.94  271.55  268.29  270.14   -0.9533
# 3     2019-02-08T08:00:00.000Z  268.75  270.58  267.83  270.47    0.1222
# 4     2019-02-11T08:00:00.000Z  271.20  271.49  270.03  270.62    0.0555
# ...                        ...     ...     ...     ...     ...       ...
# 1255  2024-01-31T08:00:00.000Z  488.62  489.08  482.86  482.88   -1.6300
# 1256  2024-02-01T08:00:00.000Z  484.63  489.23  483.80  489.20    1.3100
# 1257  2024-02-02T08:00:00.000Z  489.65  496.05  489.30  494.35    1.0500
# 1258  2024-02-05T08:00:00.000Z  493.69  494.38  490.23  492.55   -0.3641
# 1259  2024-02-06T08:00:00.000Z  493.52  494.32  492.05  493.98    0.2903
#
#       % Change vs Average     Volume
# 0                  0.3630   79552774
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1260 non-null   object
#  1   Open                 1260 non-null   float64
#  2   High                 1260 non-null   float64
#  3   Low                  1260 non-null   float64
#  4   Close                1260 non-null   float64
#  5   % Change             1258 non-null   float64
#  6   % Change vs Average  1260 non-null   float64
#  7   Volume               1260 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 78.9+ KB

# %%
#convert date type
df.Date = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1260 non-null   datetime64[ns, UTC]
#  1   Open                 1260 non-null   float64
#  2   High                 1260 non-null   float64
#  3   Low                  1260 non-null   float64
#  4   Close                1260 non-null   float64
#  5   % Change             1258 non-null   float64
#  6   % Change vs Average  1260 non-null   float64
#  7   Volume               1260 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(6), int64(1)
# memory usage: 78.9 KB

# %%
#Extract only the date 
df.Date = df.Date.dt.date

# %%
df
# Out:
#             Date    Open    High     Low   Close  % Change  \
# 0     2019-02-05  272.44  273.44  271.88  273.10    0.4192
# 1     2019-02-06  272.79  273.34  271.92  272.74   -0.1318
# 2     2019-02-07  270.94  271.55  268.29  270.14   -0.9533
# 3     2019-02-08  268.75  270.58  267.83  270.47    0.1222
# 4     2019-02-11  271.20  271.49  270.03  270.62    0.0555
# ...          ...     ...     ...     ...     ...       ...
# 1255  2024-01-31  488.62  489.08  482.86  482.88   -1.6300
# 1256  2024-02-01  484.63  489.23  483.80  489.20    1.3100
# 1257  2024-02-02  489.65  496.05  489.30  494.35    1.0500
# 1258  2024-02-05  493.69  494.38  490.23  492.55   -0.3641
# 1259  2024-02-06  493.52  494.32  492.05  493.98    0.2903
#
#       % Change vs Average     Volume
# 0                  0.3630   79552774
# 1                 -0.1880   58347791
# 2                 -1.0100   95481961
# 3                  0.0660   75788861
# 4                 -0.0007   68021423
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1260 non-null   object
#  1   Open                 1260 non-null   float64
#  2   High                 1260 non-null   float64
#  3   Low                  1260 non-null   float64
#  4   Close                1260 non-null   float64
#  5   % Change             1258 non-null   float64
#  6   % Change vs Average  1260 non-null   float64
#  7   Volume               1260 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 78.9+ KB

# %%
#convert date type
df.Date = pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1260 non-null   datetime64[ns]
#  1   Open                 1260 non-null   float64
#  2   High                 1260 non-null   float64
#  3   Low                  1260 non-null   float64
#  4   Close                1260 non-null   float64
#  5   % Change             1258 non-null   float64
#  6   % Change vs Average  1260 non-null   float64
#  7   Volume               1260 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 78.9 KB

# %%
# Set 'Date' as the index
df.set_index('Date', inplace=True)

# %%
df
# Out:
#               Open    High     Low   Close  % Change  % Change vs Average  \
# Date
# 2019-02-05  272.44  273.44  271.88  273.10    0.4192               0.3630
# 2019-02-06  272.79  273.34  271.92  272.74   -0.1318              -0.1880
# 2019-02-07  270.94  271.55  268.29  270.14   -0.9533              -1.0100
# 2019-02-08  268.75  270.58  267.83  270.47    0.1222               0.0660
# 2019-02-11  271.20  271.49  270.03  270.62    0.0555              -0.0007
# ...            ...     ...     ...     ...       ...                  ...
# 2024-01-31  488.62  489.08  482.86  482.88   -1.6300              -1.6900
# 2024-02-01  484.63  489.23  483.80  489.20    1.3100               1.2500
# 2024-02-02  489.65  496.05  489.30  494.35    1.0500               0.9966
# 2024-02-05  493.69  494.38  490.23  492.55   -0.3641              -0.4203
# 2024-02-06  493.52  494.32  492.05  493.98    0.2903               0.2342
#
#                Volume
# Date
# 2019-02-05   79552774
# ...

# %%
#plot data
mpf.plot(df)
# Out:
# C:\Users\sheha\anaconda3\envs\dojo-env\lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
# plot as a line curve with volume
mpf.plot(df, type='line', volume=True)

# %%
#plot data for 2020-09
mpf.plot(df['2020-09-01':'2020-10-01'], volume =True)

# %%
#plot candlestick chart
mpf.plot(df['2020-09-01':'2020-10-01'], type = 'candle', volume=True)

# %%
#add moving average to the candlestick chart
mpf.plot(df['2020-09':'2020-12'], type = 'candle', volume=True, mav=(10), tight_layout=True)

# %%
mpf.plot(df['2020-09':'2020-12'], type = 'candle', volume=True, mav=(10), 
         figratio= (20,12),
         title= 'SPY Price Sep-Dec 2020',
         tight_layout=True,
        style= 'yahoo' )
